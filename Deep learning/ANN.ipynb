# %%
import numpy as np
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
x_train = tf.keras.utils.normalize(x_train,axis = 1)
x_test = tf.keras.utils.normalize(x_test,axis = 1)

# %%
model = Sequential()
model.add(Flatten())

# %%
model.add(Dense(128,activation='relu',input_shape=(28,28,1)))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss= 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=25,validation_data=(x_test,y_test))
# Out:
# Epoch 1/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 24s 13ms/step - accuracy: 0.9978 - loss: 0.0086 - val_accuracy: 0.9763 - val_loss: 0.1366
# Epoch 2/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9978 - loss: 0.0095 - val_accuracy: 0.9782 - val_loss: 0.1268
# Epoch 3/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9979 - loss: 0.0082 - val_accuracy: 0.9779 - val_loss: 0.1428
# Epoch 4/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9982 - loss: 0.0080 - val_accuracy: 0.9769 - val_loss: 0.1493
# Epoch 5/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9980 - loss: 0.0074 - val_accuracy: 0.9753 - val_loss: 0.1751
# Epoch 6/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9980 - loss: 0.0083 - val_accuracy: 0.9736 - val_loss: 0.1551
# Epoch 7/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9977 - loss: 0.0095 - val_accuracy: 0.9775 - val_loss: 0.1413
# Epoch 8/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.9769 - val_loss: 0.1480
# Epoch 9/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9973 - loss: 0.0097 - val_accuracy: 0.9779 - val_loss: 0.1427
# Epoch 10/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9978 - loss: 0.0079 - val_accuracy: 0.9752 - val_loss: 0.1758
# Epoch 11/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.9979 - loss: 0.0092 - val_accuracy: 0.9756 - val_loss: 0.1602
# Epoch 12/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - accuracy: 0.9982 - loss: 0.0079 - val_accuracy: 0.9782 - val_loss: 0.1600
# Epoch 13/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.9980 - loss: 0.0096 - val_accuracy: 0.9741 - val_loss: 0.1598
# Epoch 14/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9980 - loss: 0.0082 - val_accuracy: 0.9774 - val_loss: 0.1785
# Epoch 15/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9982 - loss: 0.0076 - val_accuracy: 0.9752 - val_loss: 0.1912
# Epoch 16/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9979 - loss: 0.0084 - val_accuracy: 0.9780 - val_loss: 0.1808
# Epoch 17/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9981 - loss: 0.0084 - val_accuracy: 0.9778 - val_loss: 0.1659
# Epoch 18/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9987 - loss: 0.0068 - val_accuracy: 0.9778 - val_loss: 0.1562
# Epoch 19/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9981 - loss: 0.0077 - val_accuracy: 0.9773 - val_loss: 0.1626
# Epoch 20/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9984 - loss: 0.0060 - val_accuracy: 0.9756 - val_loss: 0.1966
# Epoch 21/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.9982 - loss: 0.0093 - val_accuracy: 0.9764 - val_loss: 0.1610
# Epoch 22/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9982 - loss: 0.0085 - val_accuracy: 0.9761 - val_loss: 0.1731
# Epoch 23/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.9981 - loss: 0.0086 - val_accuracy: 0.9780 - val_loss: 0.1852
# Epoch 24/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.9984 - loss: 0.0073 - val_accuracy: 0.9766 - val_loss: 0.1870
# Epoch 25/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 11ms/step - accuracy: 0.9986 - loss: 0.0058 - val_accuracy: 0.9749 - val_loss: 0.1871

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.show()

# %%
plt.plot(history.history['val_accuracy'])
plt.show()
