# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\Sukhmeetkour\\OneDrive\\Documents\\housing data.csv")
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
correlation = df.corr(numeric_only=True)
print(correlation)
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(correlation, annot=True, cmap="YlGnBu")
plt.show()

# %%
def remove_outliers(House, column):
    Q1 = House[column].quantile(0.25)
    Q3 = House[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return House[(House[column] >= lower) & (House[column] <= upper)]

df_filtered = df.copy()
for col in ['price', 'sqft_living', 'bedrooms', 'bathrooms']:
    df_filtered = remove_outliers(df_filtered, col)

print("Filtered dataset shape:", df_filtered.shape)
# Out:
# Filtered dataset shape: (4150, 18)

# %%
# Area vs Price
plt.scatter(df_filtered['sqft_living'], df_filtered['price'])
plt.xlabel("Living Area (sqft)")
plt.ylabel("Price")
plt.title("Area vs House Price (Outliers Removed)")
plt.show()

# Bedrooms vs Price
sns.boxplot(x='bedrooms', y='price', data=df_filtered)
plt.title("Bedrooms vs Price (Outliers Removed)")
plt.show()

# Bathrooms vs Price
sns.boxplot(x='bathrooms', y='price', data=df_filtered)
plt.title("Bathrooms vs Price (Outliers Removed)")
plt.show()

# %%
import numpy as np
if 'furnishing_status' not in df.columns:
    df['furnishing_status'] = np.random.choice(['Furnished', 'Semi-Furnished', 'Unfurnished'], size=len(df))

sns.barplot(x='furnishing_status', y='price', data=df)
plt.title('Furnishing Status vs House Price')
plt.show()

# %%
if 'mainroad' not in df.columns:
    df['mainroad'] = np.random.choice(['yes', 'no'], size=len(df))

sns.violinplot(x='mainroad', y='price', data=df)
plt.title('Price vs Main Road')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['furnishing_status'] = le.fit_transform(df['furnishing_status'])
df['mainroad'] = le.fit_transform(df['mainroad'])

# %%
from sklearn.preprocessing import LabelEncoder
Lab_en = LabelEncoder()
cat_col = ["street","city" ,"statezip","country"]        
for i in df[cat_col]:
    df[i]= Lab_en.fit_transform(df[i])

# %%
x = df.drop("price",axis=1)
y=df["price"]

# %%
x
# Out:
#                      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-05-02 00:00:00       3.0       1.50         1340      7912     1.5
# 1     2014-05-02 00:00:00       5.0       2.50         3650      9050     2.0
# 2     2014-05-02 00:00:00       3.0       2.00         1930     11947     1.0
# 3     2014-05-02 00:00:00       3.0       2.25         2000      8030     1.0
# 4     2014-05-02 00:00:00       4.0       2.50         1940     10500     1.0
# ...                   ...       ...        ...          ...       ...     ...
# 4595  2014-07-09 00:00:00       3.0       1.75         1510      6360     1.0
# 4596  2014-07-09 00:00:00       3.0       2.50         1460      7573     2.0
# 4597  2014-07-09 00:00:00       3.0       2.50         3010      7014     2.0
# 4598  2014-07-10 00:00:00       4.0       2.00         2090      6630     1.0
# 4599  2014-07-10 00:00:00       3.0       2.50         1490      8102     2.0
#
# ...

# %%
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
LinReg = LinearRegression()
LinReg.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18564\1632986739.py in ?()
#       1 from sklearn.linear_model import LinearRegression
#       2 LinReg = LinearRegression()
# ----> 3 LinReg.fit(x_train,y_train)
#       4 y_pred = LinReg.predict(x_test)
#       5 y_pred
#
# c:\Users\Sukhmeetkour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1361                 skip_parameter_validation=(
#    1362                     prefer_skip_nested_validation or global_skip_validation
#    1363                 )
#    1364             ):
# -> 1365                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Sukhmeetkour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     614         n_jobs_ = self.n_jobs
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Encode binary columns
le = LabelEncoder()
df['furnishing_status'] = le.fit_transform(df['furnishing_status'])
df['mainroad'] = le.fit_transform(df['mainroad'])

# Encode multi-category columns
Lab_en = LabelEncoder()
cat_col = ["street", "city", "statezip", "country"]
for col in cat_col:
    df[col] = Lab_en.fit_transform(df[col])

# Define X and y
x = df.drop("price", axis=1)
y = df["price"]

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# Linear Regression
LinReg = LinearRegression()
LinReg.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 # Encode binary columns
#       6 le = LabelEncoder()
# ----> 7 df['furnishing_status'] = le.fit_transform(df['furnishing_status'])
#       8 df['mainroad'] = le.fit_transform(df['mainroad'])
#      10 # Encode multi-category columns
#
# NameError: name 'df' is not defined
